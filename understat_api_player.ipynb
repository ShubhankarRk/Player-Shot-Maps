# %%
import pandas as pd
import understatapi

client = understatapi.UnderstatClient()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
player = client.player(player='647').get_shot_data()
player[0]
# Out:
# {'id': '14642',
#  'minute': '83',
#  'result': 'BlockedShot',
#  'X': '0.795',
#  'Y': '0.32099998474121094',
#  'xG': '0.04750959947705269',
#  'player': 'Harry Kane',
#  'h_a': 'a',
#  'player_id': '647',
#  'situation': 'OpenPlay',
#  'season': '2014',
#  'shotType': 'RightFoot',
#  'match_id': '4754',
#  'h_team': 'West Ham',
#  'a_team': 'Tottenham',
#  'h_goals': '0',
#  'a_goals': '1',
#  'date': '2014-08-16 15:00:00',
#  'player_assisted': 'Andros Townsend',
#  'lastAction': 'Pass'}

# %%
df = pd.DataFrame(player)
df
# Out:
#           id minute       result                     X                    Y  \
# 0      14642     83  BlockedShot                 0.795  0.32099998474121094
# 1      15400     81      OwnGoal  0.029000000953674318   0.5820000076293945
# 2      16333     68    SavedShot    0.9059999847412109  0.46900001525878904
# 3      16901     58    SavedShot    0.9169999694824219  0.46299999237060546
# 4      16909     89         Goal    0.7609999847412109                0.415
# ...      ...    ...          ...                   ...                  ...
# 1409  632984     30         Goal    0.9230000305175782                 0.47
# 1410  632987     41  BlockedShot    0.9269999694824219  0.28899999618530275
# 1411  632998     56  BlockedShot    0.8669999694824219  0.32799999237060545
# 1412  634417     79   ShotOnPost    0.8830000305175781   0.5940000152587891
# 1413  634420     85         Goal    0.9059999847412109  0.49700000762939456
#
# ...

# %%
df.to_csv("trial.csv",index=False)

# %%
df.iloc[0:3]
# Out:
#       id minute       result                     X                    Y  \
# 0  14642     83  BlockedShot                 0.795  0.32099998474121094
# 1  15400     81      OwnGoal  0.029000000953674318   0.5820000076293945
# 2  16333     68    SavedShot    0.9059999847412109  0.46900001525878904
#
#                     xG      player h_a player_id situation season  \
# 0  0.04750959947705269  Harry Kane   a       647  OpenPlay   2014
# 1                    0  Harry Kane   a       647  SetPiece   2014
# 2   0.4358299970626831  Harry Kane   h       647  OpenPlay   2014
#
#         shotType match_id      h_team            a_team h_goals a_goals  \
# 0      RightFoot     4754    West Ham         Tottenham       0       1
# 1  OtherBodyPart     4724  Sunderland         Tottenham       2       2
# 2       LeftFoot     4715   Tottenham  Newcastle United       1       2
#
#                   date  player_assisted lastAction
# 0  2014-08-16 15:00:00  Andros Townsend       Pass
# ...
